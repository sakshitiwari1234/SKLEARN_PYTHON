# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshitiwari1234/SKLEARN_PYTHON/blob/main/Label_Encoder_AND_Ordinal_Encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/label_Ordinal_encoder_sklearn_tutorial_3___.csv")

# %%
df
# Out:
#    Unnamed: 0    fuel seller_type transmission        owner
# 0           0  petrol  individual       manual  first owner
# 1           1  petrol  individual       manual  first owner
# 2           2  diesel  individual       manual  first owner
# 3           3  diesel  individual       manual  first owner
# 4           4  diesel  individual       manual  first owner

# %% [markdown]
# ### Data can be divided into two categories -
#
# numerical data and categorical data.
# when the data given , is in form of numbers it is called as numerical data, whereas data in form of categories division it is called as categorical data.

# %% [markdown]
# In this lecture, we are studying the library - scikit-learn in which we study about various techniques and process to handle the data while data modelling which are requirred to build and transform a machine learning model.
#
# this lecture holds about the label and ordinal encode in scikitlearn library.
#
# label order is the naming which we give , and ordinal order in the way we do classify data in some order accordingly.
#
# so , look we are given different columns , in this the fuel column is the target column which will tell us that wheterh a particular car named is petrol fueled and diesel fueled.

# %% [markdown]
# Therefore , in order to make the machine work in proper way , we use categorical tranformation of data by assigning  the same category names a particular sort of numbers.

# %% [markdown]
# categories are of two types - nominal ordinal extc.

# %% [markdown]
# ### using python

# %%
df
# Out:
#    Unnamed: 0    fuel seller_type transmission        owner
# 0           0  petrol  individual       manual  first owner
# 1           1  petrol  individual       manual  first owner
# 2           2  diesel  individual       manual  first owner
# 3           3  diesel  individual       manual  first owner
# 4           4  diesel  individual       manual  first owner

# %%
df['transmission'].value_counts()
# Out:
# transmission
# manual    5
# Name: count, dtype: int64

# %%
df['transmission'] = df['transmission'].map({'manual': 0})

# %%
df
# Out:
#    Unnamed: 0    fuel seller_type transmission        owner  0
# 0           0  petrol  individual       manual  first owner  0
# 1           1  petrol  individual       manual  first owner  0
# 2           2  diesel  individual       manual  first owner  0
# 3           3  diesel  individual       manual  first owner  0
# 4           4  diesel  individual       manual  first owner  0

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# 0    5
# Name: count, dtype: int64

# %%
df['seller_type'] = df['seller_type'].map({'individual': 0})

# %%
df
# Out:
#    Unnamed: 0    fuel  seller_type  transmission        owner  0  seller_new  \
# 0           0  petrol          NaN             0  first owner  0           0
# 1           1  petrol          NaN             0  first owner  0           0
# 2           2  diesel          NaN             0  first owner  0           0
# 3           3  diesel          NaN             0  first owner  0           0
# 4           4  diesel          NaN             0  first owner  0           0
#
#    trans_new
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df.sample(5)
# Out:
#    Unnamed: 0    fuel  seller_type  transmission        owner  0  seller_new  \
# 3           3  diesel          NaN             0  first owner  0           0
# 2           2  diesel          NaN             0  first owner  0           0
# 0           0  petrol          NaN             0  first owner  0           0
# 4           4  diesel          NaN             0  first owner  0           0
# 1           1  petrol          NaN             0  first owner  0           0
#
#    trans_new
# 3          0
# 2          0
# 0          0
# 4          0
# 1          0

# %%
df
# Out:
#    Unnamed: 0    fuel  seller_type  transmission        owner  0  seller_new  \
# 0           0  petrol          NaN             0  first owner  0           0
# 1           1  petrol          NaN             0  first owner  0           0
# 2           2  diesel          NaN             0  first owner  0           0
# 3           3  diesel          NaN             0  first owner  0           0
# 4           4  diesel          NaN             0  first owner  0           0
#
#    trans_new
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# Appplying label encoder.

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain , xtest , ytrain , ytest = train_test_split(df.drop('fuel', axis=1), df['fuel'], test_size = 0.2)

# %%
xtrain
# Out:
#    Unnamed: 0  seller_type  transmission        owner  0  seller_new  \
# 1           1          NaN             0  first owner  0           0
# 4           4          NaN             0  first owner  0           0
# 0           0          NaN             0  first owner  0           0
# 3           3          NaN             0  first owner  0           0
#
#    trans_new
# 1          0
# 4          0
# 0          0
# 3          0

# %%
ytrain
# Out:
# 1    petrol
# 4    diesel
# 0    petrol
# 3    diesel
# Name: fuel, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
le = LabelEncoder()

# %% [markdown]
# // target variable and predicted variables only uses labelencoder always remeber this.

# %%
le = LabelEncoder()

# %%
y_train_scaled = le.fit_transform(ytrain)

# %%
y_test_scaled = le.transform(ytest)

# %%
y_train_scaled
# Out:
# array([1, 0, 1, 0])

# %%
y_train_scaled
# Out:
# array([1, 0, 1, 0])

# %%
y_test_scaled
# Out:
# array([0])

# %% [markdown]
# labelEncoder is always used for the targeting and predicted variables / columns.
#
# ordinal encoder is always used for the dependent variables or columns.

# %%
oe  =OrdinalEncoder()

# %%
xtrain = oe.fit_transform(xtrain)
# xtest = oe.transform(xtest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-c5049b794129> in <cell line: 1>()
# ----> 1 xtrain = oe.fit_transform(xtrain)
#       2 # xtest = oe.transform(xtest)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
# ...
